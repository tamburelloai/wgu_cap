# %%
import pandas as pd
import plotly.express as px


df = pd.read_csv('data/weather_dataset.csv')

# %%
df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  19656.000000  19656.000000  19656.000000  19656.000000  19656.000000
# mean      12.873016      7.075702      0.298291      7.697558      3.465201
# std       11.582079     10.437432      1.276158      3.030351      1.900424
# min      -25.000000    -28.000000      0.000000      2.600000      1.000000
# 25%        4.000000      0.000000      0.000000      5.200000      2.000000
# 50%       13.000000      8.000000      0.000000      8.700000      3.000000
# 75%       23.000000     15.000000      0.000000      9.100000      5.000000
# max       35.000000     25.000000     15.400000     14.500000      8.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       19656.000000  19656.000000  19656.000000  19656.000000
# mean           45.890110      3.472934      8.050417     10.182641
# std            30.821232      9.711125     13.232625     11.205262
# ...

# %%
df.corr()
# Out:
#                    maxtempC  mintempC  totalSnow_cm   sunHour   uvIndex  \
# maxtempC           1.000000  0.954044     -0.287392  0.706848  0.935338
# mintempC           0.954044  1.000000     -0.285808  0.609571  0.881601
# totalSnow_cm      -0.287392 -0.285808      1.000000 -0.288222 -0.290735
# sunHour            0.706848  0.609571     -0.288222  1.000000  0.728792
# uvIndex            0.935338  0.881601     -0.290735  0.728792  1.000000
# moon_illumination -0.011382  0.002577     -0.000933 -0.021641  0.005146
# DewPointC          0.815475  0.889330     -0.201880  0.450145  0.728734
# FeelsLikeC         0.965341  0.967045     -0.287441  0.646324  0.900598
# HeatIndexC         0.963405  0.967243     -0.277373  0.650320  0.901796
# WindChillC         0.966052  0.964910     -0.289828  0.642095  0.898393
# WindGustKmph      -0.235889 -0.153077      0.099628 -0.234451 -0.263017
# cloudcover        -0.465537 -0.348963      0.286404 -0.700528 -0.502080
# ...

# %%
cluster_ids.cLabel.value_counts()
# Out:
# 1    3178
# 6    2578
# 5    2401
# 3    2239
# 4    2119
# 2    2020
# 7    1934
# 0    1723
# 8    1464
# Name: cLabel, dtype: int64

# %%
def plot_components():
    values = pc.values
    x, y, z = [values[:, i] for i in range(values.shape[1])]
    fig = px.scatter_3d(x=x[:10], y=y[:10], z=z[:10])
    fig.show()

plot_components()
# Out:
# <div>                            <div id="ca8b353a-7b99-4c27-a6ad-be069a07ce8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca8b353a-7b99-4c27-a6ad-be069a07ce8e")) {                    Plotly.newPlot(                        "ca8b353a-7b99-4c27-a6ad-be069a07ce8e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[15.710097807153224,11.728248953218422,7.739124032714447,2.7517466817823486,1.820764728731278,-0.103748985641933,-1.99013123977039,-2.346233794314104,-2.6672731860143024,-4.020092441644498],"y":[18.87727596751378,20.52477944283944,22.134163299663197,23.41227491041117,26.31245
# ...
